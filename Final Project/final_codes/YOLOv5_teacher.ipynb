# %% [markdown]
# ## Download Custom Yolo Dataset

# %%
# !nvidia-smi
# Out:
# Sun Dec 11 22:06:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0    51W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5  
# !unzip "/content/drive/MyDrive/Colab Code/RobotPerception/Project/TrafficSign/yolo_dataset.zip" -d "/content/yolov5"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-17_11-07-34-368976_k0_part1.txt
#  extracting: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-22_11-39-30-632358_k0_part1.txt
#  extracting: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-17_12-31-13-832951_k0_part2.txt
#   inflating: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-22_14-55-06-100560_k0_part1.txt
#   inflating: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-24_18-10-31-314041_k0_part2.txt
#  extracting: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-24_17-25-29-311358_k0_part2.txt
#   inflating: /content/yolov5/content/yolo_dataset/traffic_light/labels/test/DE_BBBR667_2015-04-24_13-14-36-732430_k0_part2.txt
# ...

# %% [markdown]
# ## Installation of YOLO
#
# Using the Ultralytics implementation of YOLOv5

# %%
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# /content/yolov5
#      |████████████████████████████████| 182 kB 4.4 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#      |████████████████████████████████| 1.6 MB 61.6 MB/s

# %% [markdown]
# ## Feature Extraction

# %%
#!cp '/content/drive/MyDrive/Colab Code/RobotPerception/Project/TrafficSign/traffic_light_teacher.zip' '/content/yolov5'
#!ls
# !unzip 'traffic_light_teacher.zip'
# Out:
# Archive:  traffic_light_teacher.zip
#    creating: content/yolov5/traffic_light/
#    creating: content/yolov5/traffic_light/training_student_model_yolov5l/
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/F1_curve.png
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/val_batch2_labels.jpg
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/confusion_matrix.png
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/val_batch2_pred.jpg
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/train_batch1.jpg
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/events.out.tfevents.1670709998.194ab6c8c752.574.0
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/PR_curve.png
#   inflating: content/yolov5/traffic_light/training_student_model_yolov5l/labels_correlogram.jpg
# ...

# %%
# !python train.py --batch -1 --epochs 15  --data 'data/traffic_data.yaml' --weights 'best.pt' --hyp hyp.scratch-high.yaml --project 'traffic_light' --name 'training_student_model_yolov5l'
# Out:
# train: weights=best.pt, cfg=, data=data/traffic_data.yaml, hyp=hyp.scratch-high.yaml, epochs=15, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=traffic_light, name=training_student_model_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !python train.py --batch -1 --epochs 15  --data 'data/traffic_data.yaml' --weights 'traffic_light/training_student_model_yolov5l/weights/best.pt' --hyp hyp.scratch-high.yaml --project 'traffic_light' --name 'training_student_model_yolov5l'
# Out:
# train: weights=traffic_light/training_student_model_yolov5l/weights/best.pt, cfg=, data=data/traffic_data.yaml, hyp=hyp.scratch-high.yaml, epochs=15, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=traffic_light, name=training_student_model_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !python train.py --batch -1 --epochs 10  --data 'data/traffic_data.yaml' --weights 'traffic_light/training_student_model_yolov5l2/weights/best.pt' --hyp hyp.scratch-high.yaml --project 'traffic_light' --name 'training_student_model_yolov5l'
# Out:
# train: weights=traffic_light/training_student_model_yolov5l2/weights/best.pt, cfg=, data=data/traffic_data.yaml, hyp=hyp.scratch-high.yaml, epochs=10, batch_size=-1, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=traffic_light, name=training_student_model_yolov5l, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-30-g342fe05 Python-3.8.16 torch-1.13.0+cu116 CUDA:0 (A100-SXM4-40GB, 40536MiB)
#
# ...

# %%
# !zip -r '/content/yolov5/traffic_light_teacher.zip' '/content/yolov5/traffic_light'
# !cp '/content/yolov5/traffic_light_teacher.zip' '/content/drive/MyDrive/Colab Code/RobotPerception/Project/TrafficSign'
# Out:
# updating: content/yolov5/traffic_light/ (stored 0%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/ (stored 0%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/F1_curve.png (deflated 12%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/val_batch2_labels.jpg (deflated 9%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/confusion_matrix.png (deflated 28%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/val_batch2_pred.jpg (deflated 9%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/train_batch1.jpg (deflated 5%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/PR_curve.png (deflated 9%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/labels_correlogram.jpg (deflated 22%)
# updating: content/yolov5/traffic_light/training_student_model_yolov5l/val_batch0_pred.jpg (deflated 9%)
# ...
